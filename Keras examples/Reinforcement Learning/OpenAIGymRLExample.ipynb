# %% [markdown]
# # Reinforcement Learning (RL) - DQN Training Example with OpenAI Gymnasium

# %% [markdown]
# **Step 1:** *System setup and dependency installation:*

# %%
pip install gymnasium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gymnasium
#   Downloading gymnasium-1.1.1-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 6.0 MB/s eta 0:00:01
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/christopherleggett/Library/Python/3.9/lib/python/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/christopherleggett/Library/Python/3.9/lib/python/site-packages (from gymnasium) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/christopherleggett/Library/Python/3.9/lib/python/site-packages (from gymnasium) (4.14.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/christopherleggett/Library/Python/3.9/lib/python/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: zipp>=3.20 in /Users/christopherleggett/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.23.0)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-1.1.1
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
import numpy as np

# %%
#Initialize the environment
#Initialize the benchmark problem for RL using the CartPole benchmark
env = gym.make('CartPole-v1')
# Set hyperparameters
alpha = 0.001          # Keep learning rate moderate
gamma = 0.99           # Keep discount factor
epsilon = 1.0          # Start with full exploration
epsilon_min = 0.01     # Go back to lower minimum
epsilon_decay = 0.995  # Moderate decay (between 0.995 and 0.99)
episodes = 300         # More episodes to see full learning curve
target_update_frequency = 10

#Initialize the state and action dimensions
state_size = env.observation_space.shape[0]
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %%
#Suppress cell warnings
import warnings
warnings.filterwarnings("ignore", message="urllib3 v2 only supports OpenSSL")

#Build the Q-network using keras
import random
from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input 
from tensorflow.keras.optimizers import Adam

def build_q_network(state_size, action_size):
    model = Sequential() 
    model.add(Input(shape=(state_size,)))
    model.add(Dense(64, activation='relu'))  
    model.add(Dense(64, activation='relu'))
    model.add(Dense(action_size, activation='linear'))
    model.compile(loss='mse', optimizer=Adam(learning_rate=alpha))
    return model

#Build the Q-network
q_network = build_q_network(state_size, action_size)
target_network = build_q_network(state_size, action_size)

# Initialize target network with same weights as main network
target_network.set_weights(q_network.get_weights())

# %%
# Train theQ-network - Optimized Version

# Training parameters
episodes = 300
batch_size = 32
target_update_frequency = 10
replay_buffer = deque(maxlen=10000)

def update_target_network():
    """Copy weights from main network to target network"""
    target_network.set_weights(q_network.get_weights())
    print("Target network updated!")

def replay_experience():
    if len(replay_buffer) < batch_size:
        return

    # Sample random batch
    batch = random.sample(replay_buffer, batch_size)
    states = np.array([e[0][0] for e in batch])
    actions = np.array([e[1] for e in batch])
    rewards = np.array([e[2] for e in batch])
    next_states = np.array([e[3][0] for e in batch])
    dones = np.array([e[4] for e in batch])
   
    # Get current and future Q-values
    current_q_values = q_network.predict(states, verbose=0)
    next_q_values = target_network.predict(next_states, verbose=0)
   
    # Update Q-values using Bellman equation
    for i in range(batch_size):
        if dones[i]:
            current_q_values[i][actions[i]] = rewards[i]
        else:
            current_q_values[i][actions[i]] = rewards[i] + gamma * np.amax(next_q_values[i])

    # Train the network
    q_network.fit(states, current_q_values, epochs=1, verbose=0)

# Store scores for analysis
training_scores = []

# Training loop
for episode in range(episodes):
    state, info = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    for time in range(500):
        # Epsilon greedy policy using main network
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            q_values = q_network.predict(state, verbose=0)
            action = np.argmax(q_values[0])
        
        next_state, reward, done, trunc, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        total_reward += reward
        
        # Store experience in replay buffer
        replay_buffer.append((state, action, reward, next_state, done))
        
        # Experience replay every 4 steps
        if len(replay_buffer) > batch_size and time % 4 == 0:
            replay_experience()
        
        state = next_state
        
        if done or trunc:
            print(f"Episode: {episode+1}/{episodes}, Score: {total_reward}, Epsilon: {epsilon:.3f}")
            break
  
    # Store score for analysis
    training_scores.append(total_reward)
    
    # Update target network periodically
    if episode % target_update_frequency == 0 and episode > 0:
        update_target_network()
    
    # Decay epsilon
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay

print("Training completed!")

# Test the trained agent
test_epsilon = epsilon
epsilon = 0
test_scores = []

for episode in range(10):
    state, info = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    for time in range(500):
        q_values = q_network.predict(state, verbose=0)
        action = np.argmax(q_values[0])
        
        next_state, reward, done, trunc, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        total_reward += reward
        state = next_state
        
        if done or trunc:
            break
    
    test_scores.append(total_reward)

# Performance summary
print(f"\nPerformance Summary:")
print(f"Average training score (last 50 episodes): {np.mean(training_scores[-50:]):.1f}")
print(f"Best training score: {max(training_scores)}")
print(f"Average test score (no exploration): {np.mean(test_scores):.1f}")
print(f"Best test score: {max(test_scores)}")

# Check if CartPole is "solved" (average of 195+ over 100 episodes)
if len(training_scores) >= 100:
    last_100_avg = np.mean(training_scores[-100:])
    print(f"Average of last 100 episodes: {last_100_avg:.1f}")
    if last_100_avg >= 195:
        print("CartPole-v1 SOLVED!")
    else:
        print(f"Need {195 - last_100_avg:.1f} more points to solve CartPole-v1")

# Restore epsilon
epsilon = test_epsilon

env.close()
# Out:
# Episode: 1/300, Score: 27.0, Epsilon: 1.000
# Episode: 2/300, Score: 20.0, Epsilon: 0.995
# Episode: 3/300, Score: 12.0, Epsilon: 0.990
# Episode: 4/300, Score: 14.0, Epsilon: 0.985
# Episode: 5/300, Score: 17.0, Epsilon: 0.980
# Episode: 6/300, Score: 20.0, Epsilon: 0.975
# Episode: 7/300, Score: 31.0, Epsilon: 0.970
# Episode: 8/300, Score: 15.0, Epsilon: 0.966
# Episode: 9/300, Score: 12.0, Epsilon: 0.961
# Episode: 10/300, Score: 12.0, Epsilon: 0.956
# Episode: 11/300, Score: 12.0, Epsilon: 0.951
# Target network updated!
# Episode: 12/300, Score: 16.0, Epsilon: 0.946
# Episode: 13/300, Score: 18.0, Epsilon: 0.942
# Episode: 14/300, Score: 50.0, Epsilon: 0.937
# Episode: 15/300, Score: 19.0, Epsilon: 0.932
# Episode: 16/300, Score: 15.0, Epsilon: 0.928
# Episode: 17/300, Score: 20.0, Epsilon: 0.923
# Episode: 18/300, Score: 11.0, Epsilon: 0.918
# Episode: 19/300, Score: 20.0, Epsilon: 0.914
# Episode: 20/300, Score: 14.0, Epsilon: 0.909
# Episode: 21/300, Score: 13.0, Epsilon: 0.905
# Target network updated!
# Episode: 22/300, Score: 19.0, Epsilon: 0.900
# Episode: 23/300, Score: 15.0, Epsilon: 0.896
# Episode: 24/300, Score: 11.0, Epsilon: 0.891
# Episode: 25/300, Score: 23.0, Epsilon: 0.887
# Episode: 26/300, Score: 15.0, Epsilon: 0.882
# Episode: 27/300, Score: 21.0, Epsilon: 0.878
# Episode: 28/300, Score: 10.0, Epsilon: 0.873
# Episode: 29/300, Score: 11.0, Epsilon: 0.869
# Episode: 30/300, Score: 17.0, Epsilon: 0.865
# Episode: 31/300, Score: 12.0, Epsilon: 0.860
# Target network updated!
# Episode: 32/300, Score: 9.0, Epsilon: 0.856
# Episode: 33/300, Score: 19.0, Epsilon: 0.852
# Episode: 34/300, Score: 16.0, Epsilon: 0.848
# Episode: 35/300, Score: 13.0, Epsilon: 0.843
# Episode: 36/300, Score: 31.0, Epsilon: 0.839
# Episode: 37/300, Score: 25.0, Epsilon: 0.835
# Episode: 38/300, Score: 15.0, Epsilon: 0.831
# Episode: 39/300, Score: 34.0, Epsilon: 0.827
# Episode: 40/300, Score: 8.0, Epsilon: 0.822
# Episode: 41/300, Score: 24.0, Epsilon: 0.818
# Target network updated!
# Episode: 42/300, Score: 13.0, Epsilon: 0.814
# Episode: 43/300, Score: 15.0, Epsilon: 0.810
# Episode: 44/300, Score: 9.0, Epsilon: 0.806
# Episode: 45/300, Score: 10.0, Epsilon: 0.802
# Episode: 46/300, Score: 31.0, Epsilon: 0.798
# Episode: 47/300, Score: 16.0, Epsilon: 0.794
# Episode: 48/300, Score: 29.0, Epsilon: 0.790
# Episode: 49/300, Score: 15.0, Epsilon: 0.786
# Episode: 50/300, Score: 11.0, Epsilon: 0.782
# Episode: 51/300, Score: 10.0, Epsilon: 0.778
# Target network updated!
# Episode: 52/300, Score: 18.0, Epsilon: 0.774
# Episode: 53/300, Score: 14.0, Epsilon: 0.771
# Episode: 54/300, Score: 11.0, Epsilon: 0.767
# Episode: 55/300, Score: 12.0, Epsilon: 0.763
# Episode: 56/300, Score: 21.0, Epsilon: 0.759
# Episode: 57/300, Score: 22.0, Epsilon: 0.755
# Episode: 58/300, Score: 17.0, Epsilon: 0.751
# Episode: 59/300, Score: 9.0, Epsilon: 0.748
# Episode: 60/300, Score: 21.0, Epsilon: 0.744
# Episode: 61/300, Score: 17.0, Epsilon: 0.740
# Target network updated!
# Episode: 62/300, Score: 12.0, Epsilon: 0.737
# Episode: 63/300, Score: 40.0, Epsilon: 0.733
# Episode: 64/300, Score: 15.0, Epsilon: 0.729
# Episode: 65/300, Score: 22.0, Epsilon: 0.726
# Episode: 66/300, Score: 22.0, Epsilon: 0.722
# Episode: 67/300, Score: 15.0, Epsilon: 0.718
# Episode: 68/300, Score: 11.0, Epsilon: 0.715
# Episode: 69/300, Score: 17.0, Epsilon: 0.711
# Episode: 70/300, Score: 17.0, Epsilon: 0.708
# Episode: 71/300, Score: 11.0, Epsilon: 0.704
# Target network updated!
# Episode: 72/300, Score: 38.0, Epsilon: 0.701
# Episode: 73/300, Score: 14.0, Epsilon: 0.697
# Episode: 74/300, Score: 39.0, Epsilon: 0.694
# Episode: 75/300, Score: 11.0, Epsilon: 0.690
# Episode: 76/300, Score: 17.0, Epsilon: 0.687
# Episode: 77/300, Score: 16.0, Epsilon: 0.683
# Episode: 78/300, Score: 99.0, Epsilon: 0.680
# Episode: 79/300, Score: 13.0, Epsilon: 0.676
# Episode: 80/300, Score: 18.0, Epsilon: 0.673
# Episode: 81/300, Score: 17.0, Epsilon: 0.670
# Target network updated!
# Episode: 82/300, Score: 8.0, Epsilon: 0.666
# Episode: 83/300, Score: 21.0, Epsilon: 0.663
# Episode: 84/300, Score: 31.0, Epsilon: 0.660
# Episode: 85/300, Score: 15.0, Epsilon: 0.656
# Episode: 86/300, Score: 66.0, Epsilon: 0.653
# Episode: 87/300, Score: 56.0, Epsilon: 0.650
# Episode: 88/300, Score: 47.0, Epsilon: 0.647
# Episode: 89/300, Score: 38.0, Epsilon: 0.643
# Episode: 90/300, Score: 49.0, Epsilon: 0.640
# Episode: 91/300, Score: 62.0, Epsilon: 0.637
# Target network updated!
# Episode: 92/300, Score: 25.0, Epsilon: 0.634
# Episode: 93/300, Score: 83.0, Epsilon: 0.631
# Episode: 94/300, Score: 18.0, Epsilon: 0.627
# Episode: 95/300, Score: 42.0, Epsilon: 0.624
# Episode: 96/300, Score: 39.0, Epsilon: 0.621
# Episode: 97/300, Score: 34.0, Epsilon: 0.618
# Episode: 98/300, Score: 34.0, Epsilon: 0.615
# Episode: 99/300, Score: 27.0, Epsilon: 0.612
# Episode: 100/300, Score: 12.0, Epsilon: 0.609
# Episode: 101/300, Score: 20.0, Epsilon: 0.606
# Target network updated!
# Episode: 102/300, Score: 48.0, Epsilon: 0.603
# Episode: 103/300, Score: 12.0, Epsilon: 0.600
# Episode: 104/300, Score: 46.0, Epsilon: 0.597
# Episode: 105/300, Score: 14.0, Epsilon: 0.594
# Episode: 106/300, Score: 11.0, Epsilon: 0.591
# Episode: 107/300, Score: 27.0, Epsilon: 0.588
# Episode: 108/300, Score: 48.0, Epsilon: 0.585
# Episode: 109/300, Score: 66.0, Epsilon: 0.582
# Episode: 110/300, Score: 35.0, Epsilon: 0.579
# Episode: 111/300, Score: 19.0, Epsilon: 0.576
# Target network updated!
# Episode: 112/300, Score: 36.0, Epsilon: 0.573
# Episode: 113/300, Score: 38.0, Epsilon: 0.570
# Episode: 114/300, Score: 20.0, Epsilon: 0.568
# Episode: 115/300, Score: 27.0, Epsilon: 0.565
# Episode: 116/300, Score: 55.0, Epsilon: 0.562
# Episode: 117/300, Score: 11.0, Epsilon: 0.559
# Episode: 118/300, Score: 41.0, Epsilon: 0.556
# Episode: 119/300, Score: 64.0, Epsilon: 0.554
# Episode: 120/300, Score: 58.0, Epsilon: 0.551
# Episode: 121/300, Score: 44.0, Epsilon: 0.548
# Target network updated!
# Episode: 122/300, Score: 60.0, Epsilon: 0.545
# Episode: 123/300, Score: 21.0, Epsilon: 0.543
# Episode: 124/300, Score: 25.0, Epsilon: 0.540
# Episode: 125/300, Score: 65.0, Epsilon: 0.537
# Episode: 126/300, Score: 108.0, Epsilon: 0.534
# Episode: 127/300, Score: 52.0, Epsilon: 0.532
# Episode: 128/300, Score: 52.0, Epsilon: 0.529
# Episode: 129/300, Score: 12.0, Epsilon: 0.526
# Episode: 130/300, Score: 89.0, Epsilon: 0.524
# Episode: 131/300, Score: 88.0, Epsilon: 0.521
# Target network updated!
# Episode: 132/300, Score: 34.0, Epsilon: 0.519
# Episode: 133/300, Score: 28.0, Epsilon: 0.516
# Episode: 134/300, Score: 47.0, Epsilon: 0.513
# Episode: 135/300, Score: 20.0, Epsilon: 0.511
# Episode: 136/300, Score: 103.0, Epsilon: 0.508
# Episode: 137/300, Score: 41.0, Epsilon: 0.506
# Episode: 138/300, Score: 16.0, Epsilon: 0.503
# Episode: 139/300, Score: 35.0, Epsilon: 0.501
# Episode: 140/300, Score: 60.0, Epsilon: 0.498
# Episode: 141/300, Score: 136.0, Epsilon: 0.496
# Target network updated!
# Episode: 142/300, Score: 22.0, Epsilon: 0.493
# Episode: 143/300, Score: 28.0, Epsilon: 0.491
# Episode: 144/300, Score: 101.0, Epsilon: 0.488
# Episode: 145/300, Score: 84.0, Epsilon: 0.486
# Episode: 146/300, Score: 98.0, Epsilon: 0.483
# Episode: 147/300, Score: 28.0, Epsilon: 0.481
# Episode: 148/300, Score: 15.0, Epsilon: 0.479
# Episode: 149/300, Score: 206.0, Epsilon: 0.476
# Episode: 150/300, Score: 82.0, Epsilon: 0.474
# Episode: 151/300, Score: 94.0, Epsilon: 0.471
# Target network updated!
# Episode: 152/300, Score: 161.0, Epsilon: 0.469
# Episode: 153/300, Score: 129.0, Epsilon: 0.467
# Episode: 154/300, Score: 107.0, Epsilon: 0.464
# Episode: 155/300, Score: 99.0, Epsilon: 0.462
# Episode: 156/300, Score: 23.0, Epsilon: 0.460
# Episode: 157/300, Score: 204.0, Epsilon: 0.458
# Episode: 158/300, Score: 119.0, Epsilon: 0.455
# Episode: 159/300, Score: 84.0, Epsilon: 0.453
# Episode: 160/300, Score: 79.0, Epsilon: 0.451
# Episode: 161/300, Score: 40.0, Epsilon: 0.448
# Target network updated!
# Episode: 162/300, Score: 37.0, Epsilon: 0.446
# Episode: 163/300, Score: 172.0, Epsilon: 0.444
# Episode: 164/300, Score: 249.0, Epsilon: 0.442
# Episode: 165/300, Score: 352.0, Epsilon: 0.440
# Episode: 166/300, Score: 76.0, Epsilon: 0.437
# Episode: 167/300, Score: 51.0, Epsilon: 0.435
# Episode: 168/300, Score: 14.0, Epsilon: 0.433
# Episode: 169/300, Score: 86.0, Epsilon: 0.431
# Episode: 170/300, Score: 163.0, Epsilon: 0.429
# Episode: 171/300, Score: 131.0, Epsilon: 0.427
# Target network updated!
# Episode: 172/300, Score: 230.0, Epsilon: 0.424
# Episode: 173/300, Score: 204.0, Epsilon: 0.422
# Episode: 174/300, Score: 241.0, Epsilon: 0.420
# Episode: 175/300, Score: 323.0, Epsilon: 0.418
# Episode: 176/300, Score: 186.0, Epsilon: 0.416
# Episode: 177/300, Score: 226.0, Epsilon: 0.414
# Episode: 178/300, Score: 77.0, Epsilon: 0.412
# Episode: 179/300, Score: 23.0, Epsilon: 0.410
# Episode: 180/300, Score: 274.0, Epsilon: 0.408
# Episode: 181/300, Score: 32.0, Epsilon: 0.406
# Target network updated!
# Episode: 182/300, Score: 12.0, Epsilon: 0.404
# Episode: 183/300, Score: 171.0, Epsilon: 0.402
# Episode: 184/300, Score: 184.0, Epsilon: 0.400
# Episode: 185/300, Score: 235.0, Epsilon: 0.398
# Episode: 186/300, Score: 43.0, Epsilon: 0.396
# Episode: 187/300, Score: 475.0, Epsilon: 0.394
# Episode: 188/300, Score: 220.0, Epsilon: 0.392
# Episode: 189/300, Score: 243.0, Epsilon: 0.390
# Episode: 190/300, Score: 229.0, Epsilon: 0.388
# Episode: 191/300, Score: 350.0, Epsilon: 0.386
# Target network updated!
# Episode: 192/300, Score: 163.0, Epsilon: 0.384
# Episode: 193/300, Score: 215.0, Epsilon: 0.382
# Episode: 194/300, Score: 243.0, Epsilon: 0.380
# Episode: 195/300, Score: 292.0, Epsilon: 0.378
# Episode: 196/300, Score: 112.0, Epsilon: 0.376
# Episode: 197/300, Score: 226.0, Epsilon: 0.374
# Episode: 198/300, Score: 174.0, Epsilon: 0.373
# Episode: 199/300, Score: 240.0, Epsilon: 0.371
# Episode: 200/300, Score: 279.0, Epsilon: 0.369
# Episode: 201/300, Score: 213.0, Epsilon: 0.367
# Target network updated!
# Episode: 202/300, Score: 290.0, Epsilon: 0.365
# Episode: 203/300, Score: 108.0, Epsilon: 0.363
# Episode: 204/300, Score: 307.0, Epsilon: 0.361
# Episode: 205/300, Score: 201.0, Epsilon: 0.360
# Episode: 206/300, Score: 359.0, Epsilon: 0.358
# Episode: 207/300, Score: 321.0, Epsilon: 0.356
# Episode: 208/300, Score: 424.0, Epsilon: 0.354
# Episode: 209/300, Score: 288.0, Epsilon: 0.353
# Episode: 210/300, Score: 287.0, Epsilon: 0.351
# Episode: 211/300, Score: 298.0, Epsilon: 0.349
# Target network updated!
# Episode: 212/300, Score: 231.0, Epsilon: 0.347
# Episode: 213/300, Score: 192.0, Epsilon: 0.346
# Episode: 214/300, Score: 105.0, Epsilon: 0.344
# Episode: 215/300, Score: 245.0, Epsilon: 0.342
# Episode: 216/300, Score: 207.0, Epsilon: 0.340
# Episode: 217/300, Score: 176.0, Epsilon: 0.339
# Episode: 218/300, Score: 267.0, Epsilon: 0.337
# Episode: 219/300, Score: 264.0, Epsilon: 0.335
# Episode: 220/300, Score: 421.0, Epsilon: 0.334
# Episode: 221/300, Score: 284.0, Epsilon: 0.332
# Target network updated!
# Episode: 222/300, Score: 201.0, Epsilon: 0.330
# Episode: 223/300, Score: 257.0, Epsilon: 0.329
# Episode: 224/300, Score: 302.0, Epsilon: 0.327
# Episode: 225/300, Score: 64.0, Epsilon: 0.325
# Episode: 226/300, Score: 220.0, Epsilon: 0.324
# Episode: 227/300, Score: 206.0, Epsilon: 0.322
# Episode: 228/300, Score: 292.0, Epsilon: 0.321
# Episode: 229/300, Score: 253.0, Epsilon: 0.319
# Episode: 230/300, Score: 411.0, Epsilon: 0.317
# Episode: 231/300, Score: 199.0, Epsilon: 0.316
# Target network updated!
# Episode: 232/300, Score: 334.0, Epsilon: 0.314
# Episode: 233/300, Score: 251.0, Epsilon: 0.313
# Episode: 234/300, Score: 158.0, Epsilon: 0.311
# Episode: 235/300, Score: 227.0, Epsilon: 0.309
# Episode: 236/300, Score: 271.0, Epsilon: 0.308
# Episode: 237/300, Score: 197.0, Epsilon: 0.306
# Episode: 238/300, Score: 225.0, Epsilon: 0.305
# Episode: 239/300, Score: 138.0, Epsilon: 0.303
# Episode: 240/300, Score: 264.0, Epsilon: 0.302
# Episode: 241/300, Score: 226.0, Epsilon: 0.300
# Target network updated!
# Episode: 242/300, Score: 241.0, Epsilon: 0.299
# Episode: 243/300, Score: 209.0, Epsilon: 0.297
# Episode: 244/300, Score: 146.0, Epsilon: 0.296
# Episode: 245/300, Score: 169.0, Epsilon: 0.294
# Episode: 246/300, Score: 218.0, Epsilon: 0.293
# Episode: 247/300, Score: 195.0, Epsilon: 0.291
# Episode: 248/300, Score: 263.0, Epsilon: 0.290
# Episode: 249/300, Score: 336.0, Epsilon: 0.288
# Episode: 250/300, Score: 234.0, Epsilon: 0.287
# Episode: 251/300, Score: 277.0, Epsilon: 0.286
# Target network updated!
# Episode: 252/300, Score: 261.0, Epsilon: 0.284
# Episode: 253/300, Score: 239.0, Epsilon: 0.283
# Episode: 254/300, Score: 347.0, Epsilon: 0.281
# Episode: 255/300, Score: 244.0, Epsilon: 0.280
# Episode: 256/300, Score: 203.0, Epsilon: 0.279
# Episode: 257/300, Score: 202.0, Epsilon: 0.277
# Episode: 258/300, Score: 302.0, Epsilon: 0.276
# Episode: 259/300, Score: 276.0, Epsilon: 0.274
# Episode: 260/300, Score: 270.0, Epsilon: 0.273
# Episode: 261/300, Score: 279.0, Epsilon: 0.272
# Target network updated!
# Episode: 262/300, Score: 225.0, Epsilon: 0.270
# Episode: 263/300, Score: 263.0, Epsilon: 0.269
# Episode: 264/300, Score: 206.0, Epsilon: 0.268
# Episode: 265/300, Score: 209.0, Epsilon: 0.266
# Episode: 266/300, Score: 300.0, Epsilon: 0.265
# Episode: 267/300, Score: 199.0, Epsilon: 0.264
# Episode: 268/300, Score: 286.0, Epsilon: 0.262
# Episode: 269/300, Score: 238.0, Epsilon: 0.261
# Episode: 270/300, Score: 223.0, Epsilon: 0.260
# Episode: 271/300, Score: 278.0, Epsilon: 0.258
# Target network updated!
# Episode: 272/300, Score: 227.0, Epsilon: 0.257
# Episode: 273/300, Score: 248.0, Epsilon: 0.256
# Episode: 274/300, Score: 332.0, Epsilon: 0.255
# Episode: 275/300, Score: 245.0, Epsilon: 0.253
# Episode: 276/300, Score: 222.0, Epsilon: 0.252
# Episode: 277/300, Score: 266.0, Epsilon: 0.251
# Episode: 278/300, Score: 189.0, Epsilon: 0.249
# Episode: 279/300, Score: 244.0, Epsilon: 0.248
# Episode: 280/300, Score: 268.0, Epsilon: 0.247
# Episode: 281/300, Score: 194.0, Epsilon: 0.246
# Target network updated!
# Episode: 282/300, Score: 258.0, Epsilon: 0.245
# Episode: 283/300, Score: 229.0, Epsilon: 0.243
# Episode: 284/300, Score: 200.0, Epsilon: 0.242
# Episode: 285/300, Score: 248.0, Epsilon: 0.241
# Episode: 286/300, Score: 261.0, Epsilon: 0.240
# Episode: 287/300, Score: 239.0, Epsilon: 0.238
# Episode: 288/300, Score: 180.0, Epsilon: 0.237
# Episode: 289/300, Score: 142.0, Epsilon: 0.236
# Episode: 290/300, Score: 210.0, Epsilon: 0.235
# Episode: 291/300, Score: 179.0, Epsilon: 0.234
# Target network updated!
# Episode: 292/300, Score: 201.0, Epsilon: 0.233
# Episode: 293/300, Score: 348.0, Epsilon: 0.231
# Episode: 294/300, Score: 167.0, Epsilon: 0.230
# Episode: 295/300, Score: 193.0, Epsilon: 0.229
# Episode: 296/300, Score: 158.0, Epsilon: 0.228
# Episode: 297/300, Score: 201.0, Epsilon: 0.227
# Episode: 298/300, Score: 218.0, Epsilon: 0.226
# Episode: 299/300, Score: 192.0, Epsilon: 0.225
# Episode: 300/300, Score: 194.0, Epsilon: 0.223
# Training completed!
#
# Performance Summary:
# Average training score (last 50 episodes): 235.6
# Best training score: 475.0
# Average test score (no exploration): 252.9
# Best test score: 393.0
# Average of last 100 episodes: 239.8
# CartPole-v1 SOLVED!

# %% [markdown]
# ## Training performance summary and plot

# %%
# Learning summary
import matplotlib.pyplot as plt

# Average scores every 10 episodes
episode_ranges = []
avg_scores = []

for i in range(0, len(training_scores), 10):
    episode_range = f"{i+1}-{min(i+10, len(training_scores))}"
    avg_score = np.mean(training_scores[i:i+10])  
    episode_ranges.append(i+5)  # Use middle of range for plotting
    avg_scores.append(avg_score)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(episode_ranges, avg_scores, 'b-o', linewidth=2, markersize=6)
plt.axhline(y=195, color='r', linestyle='--', label='Solved threshold (195)')
plt.xlabel('Episode')
plt.ylabel('Average Score')
plt.title('DQN Training Progress (10-Episode Averages)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
